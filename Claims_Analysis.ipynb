# %%
import pandas as pd
import numpy as np

# %%
my_dataset = pd.read_csv("/Users/ds_learner51/Downloads/_car-insurance claim.csv")
my_dataset.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %% [markdown]
# CHECK FOR NULLS

# %%
my_dataset.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
print(my_dataset.shape)
# Out:
# (381109, 12)

# %%
print(my_dataset.columns)
# Out:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage', 'Response'],
#       dtype='object')

# %%
print(my_dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.9+ MB
# None

# %%
my_dataset["Response"].value_counts()
# Out:
# 0    334399
# 1     46710
# Name: Response, dtype: int64

# %% [markdown]
# PLOTTING

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
my_dataset.describe()
# Out:
#                   id            Age  Driving_License    Region_Code  \
# count  381109.000000  381109.000000    381109.000000  381109.000000
# mean   190555.000000      38.822584         0.997869      26.388807
# std    110016.836208      15.511611         0.046110      13.229888
# min         1.000000      20.000000         0.000000       0.000000
# 25%     95278.000000      25.000000         1.000000      15.000000
# 50%    190555.000000      36.000000         1.000000      28.000000
# 75%    285832.000000      49.000000         1.000000      35.000000
# max    381109.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel  \
# count       381109.000000   381109.000000         381109.000000
# mean             0.458210    30564.389581            112.034295
# std              0.498251    17213.155057             54.203995
# min              0.000000     2630.000000              1.000000
# ...

# %%
my_dataset["Response"].value_counts()
# Out:
# 0    334399
# 1     46710
# Name: Response, dtype: int64

# %% [markdown]
# Number of Claims Approved by Denied

# %%
sns.countplot(my_dataset.Response)
plt.title('Approved Claims vs Denied Claims ')
# Show the plot
plt.show()
# Out:
# /Users/ds_learner51/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
my_dataset['Region_Code'].value_counts().plot(kind="bar")
plt.show()

# %% [markdown]
# Average annual price By Vehicle age

# %%
my_dataset.groupby(['Vehicle_Age']).mean().plot(kind='pie', y='Annual_Premium')
# Out:
# <AxesSubplot:ylabel='Annual_Premium'>

# %%
sns.scatterplot(x=my_dataset['Age'],y=my_dataset['Annual_Premium'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Annual_Premium'>

# %% [markdown]
# GROUP AGE

# %%
my_dataset['Age_group'] = np.where(my_dataset['Age']<30, '20s',
                          np.where(my_dataset['Age']<40, '30s',
                          np.where(my_dataset['Age']<50, '40s',
                          np.where(my_dataset['Age']<60, '50s',
                          np.where(my_dataset['Age']<70, '60s',
                          np.where(my_dataset['Age']<80, '70s', '80s'))))))

# %%
my_dataset.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response Age_group
# 0         1       40s
# 1         0       70s
# 2         1       40s
# ...

# %% [markdown]
# AGE GROUP BY NUMBER OF CLAIMS

# %%
my_dataset['Age_group'].value_counts().plot(kind="bar")
plt.show()
